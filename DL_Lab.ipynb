# %% [markdown]
# <a href="https://colab.research.google.com/github/piru24/DL_LABS/blob/main/DL_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import division, print_function, unicode_literals

# %%
import numpy as np

# %%
np.random.rand(3,4)
# Out:
# array([[0.97241646, 0.08017829, 0.13353355, 0.63813441],
#        [0.23732396, 0.8931712 , 0.35173326, 0.62558816],
#        [0.58149421, 0.41904065, 0.35754631, 0.29900729]])

# %%
np.random.rand(4,4)
# Out:
# array([[0.91666566, 0.21421433, 0.42136106, 0.24299869],
#        [0.73560177, 0.59895943, 0.28410228, 0.56579874],
#        [0.11361521, 0.81582752, 0.34384327, 0.55302944],
#        [0.10755571, 0.39831882, 0.24526705, 0.60342613]])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from __future__ import division, print_function, unicode_literals

# %%
import matplotlib

# %%
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

figure = plt.figure(1, figsize = (12, 4))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0.1)
plt.show()

# %%
# %matplotlib inline
